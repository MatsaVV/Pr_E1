# %%
import requests
import pandas as pd
from dotenv import load_dotenv
import os

# %%
load_dotenv()
api_key = os.getenv("API_KEY")


# Liste des auteurs pour lesquels récupérer les livres
authors = [
    "Jack London",
    "Romain Gary",
    "Fyodor Dostoevsky",
    "Stefan Zweig",
    "Joseph Kessel",
    "Victor Hugo",
    "Jules Verne",
    "Edgar Allan Poe",
    "Leo Tolstoy",
    "George Orwell"
]

# Liste pour stocker les données des livres
books_data = []

# Fonction pour interroger Google Books API
def get_books_by_author(author_name):
    url = f"https://www.googleapis.com/books/v1/volumes"
    params = {
        "q": f"inauthor:{author_name}",
        "key": API_KEY,
        "maxResults": 10  # Limiter à 10 résultats par auteur
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Erreur pour {author_name}: {response.status_code}")
        return None

# Parcourir les auteurs et récupérer leurs livres
for author in authors:
    print(f"Recherche des livres pour : {author}")
    data = get_books_by_author(author)
    if data and "items" in data:
        for item in data["items"]:
            volume_info = item.get("volumeInfo", {})
            books_data.append({
                "Author": author,
                "Title": volume_info.get("title", "N/A"),
                "Published Date": volume_info.get("publishedDate", "N/A"),
                "Categories": ", ".join(volume_info.get("categories", [])) if "categories" in volume_info else "N/A",
                "Description": volume_info.get("description", "N/A"),
                "Page Count": volume_info.get("pageCount", "N/A"),
                "ISBN_10": next((id["identifier"] for id in volume_info.get("industryIdentifiers", []) if id["type"] == "ISBN_10"), "N/A"),
                "ISBN_13": next((id["identifier"] for id in volume_info.get("industryIdentifiers", []) if id["type"] == "ISBN_13"), "N/A"),
                "Preview Link": volume_info.get("previewLink", "N/A")
            })
    else:
        print(f"Aucun livre trouvé pour {author}")

# Convertir les données en DataFrame
df = pd.DataFrame(books_data)

# Afficher un aperçu des résultats
df
# Out:
# Recherche des livres pour : Jack London
# Recherche des livres pour : Romain Gary
# Recherche des livres pour : Fyodor Dostoevsky
# Recherche des livres pour : Stefan Zweig
# Recherche des livres pour : Joseph Kessel
# Recherche des livres pour : Victor Hugo
# Recherche des livres pour : Jules Verne
# Recherche des livres pour : Edgar Allan Poe
# Recherche des livres pour : Leo Tolstoy
# Recherche des livres pour : George Orwell
#            Author                                              Title  \
# 0     Jack London                                 La force des forts
# 1     Jack London                                        Martin Eden
# 2     Jack London                                         Croc-Blanc
# 3     Jack London                               Le Peuple de l'abîme
# 4     Jack London                                  Construire un feu
# ..            ...                                                ...
# 95  George Orwell                  Mil neuf cent quatre-vingt-quatre
# 96  George Orwell                   Sommes-nous ce que nous lisons ?
# 97  George Orwell  La Ferme des animaux de George Orwell (fiche d...
# 98  George Orwell                                               1984
# 99  George Orwell                               La ferme des animaux
#
#                Published Date            Categories  \
# 0                  2022-05-26               Fiction
# 1                  2023-01-03               Fiction
# 2                  2019-01-28      Juvenile Fiction
# 3                  2023-01-25  Literary Collections
# 4                  2022-12-11               Fiction
# ..                        ...                   ...
# 95  2021-01-07T00:00:00+01:00               Fiction
# 96                 2022-04-13    Literary Criticism
# 97                 2019-10-22                   N/A
# 98                 2021-06-01               Fiction
# 99                 2021-09-17               Fiction
#
#                                           Description Page Count     ISBN_10  \
# 0   La Force des forts (titre original : The Stren...         26  2322423041
# 1   Martin Eden est un jeune marin au long cours. ...        434         N/A
# 2   L'aventure de Croc Blanc, d'abord publiée en 1...        170  2322127868
# 3   Durant l'été 1902, Jack London va descendre da...        268         N/A
# 4   Résumé de la nouvelle qui donne son titre à ce...        244         N/A
# ..                                                ...        ...         ...
# 95                                Nouvelle traduction        352  2072924146
# 96  « C’est lorsqu’on commence à entretenir une re...         49  2755508183
# 97  Venez découvrir le roman de George Orwell grâc...         42  2759303950
# 98  Écrit en 1948, publié en 1949, le célèbre 1984...        318  2381271740
# 99  La Ferme des animaux (titre original : Animal ...        100  0369406478
#
#           ISBN_13                                       Preview Link
# 0   9782322423040  http://books.google.fr/books?id=CsdxEAAAQBAJ&p...
# 1   9791041916948  http://books.google.fr/books?id=WeKoEAAAQBAJ&p...
# 2   9782322127863  http://books.google.fr/books?id=04eFDwAAQBAJ&p...
# 3   9791041916931  http://books.google.fr/books?id=a0WwEAAAQBAJ&p...
# 4   9791041916887  http://books.google.fr/books?id=jjixEAAAQBAJ&p...
# ..            ...                                                ...
# 95  9782072924149  http://books.google.fr/books?id=_9cMEAAAQBAJ&p...
# 96  9782755508185  http://books.google.fr/books?id=bUhkEAAAQBAJ&p...
# 97  9782759303953  http://books.google.fr/books?id=_IHgygEACAAJ&d...
# 98  9782381271743  http://books.google.fr/books?id=DNMwEAAAQBAJ&p...
# 99  9780369406477  http://books.google.fr/books?id=3JpDEAAAQBAJ&p...
#
# [100 rows x 9 columns]

# %%
df = df.drop(columns=['ISBN_10', 'ISBN_13', 'Preview Link'])
df
# Out:
#            Author                                              Title  \
# 0     Jack London                                 La force des forts
# 1     Jack London                                        Martin Eden
# 2     Jack London                                         Croc-Blanc
# 3     Jack London                               Le Peuple de l'abîme
# 4     Jack London                                  Construire un feu
# ..            ...                                                ...
# 95  George Orwell                  Mil neuf cent quatre-vingt-quatre
# 96  George Orwell                   Sommes-nous ce que nous lisons ?
# 97  George Orwell  La Ferme des animaux de George Orwell (fiche d...
# 98  George Orwell                                               1984
# 99  George Orwell                               La ferme des animaux
#
#                Published Date            Categories  \
# 0                  2022-05-26               Fiction
# 1                  2023-01-03               Fiction
# 2                  2019-01-28      Juvenile Fiction
# 3                  2023-01-25  Literary Collections
# 4                  2022-12-11               Fiction
# ..                        ...                   ...
# 95  2021-01-07T00:00:00+01:00               Fiction
# 96                 2022-04-13    Literary Criticism
# 97                 2019-10-22                   N/A
# 98                 2021-06-01               Fiction
# 99                 2021-09-17               Fiction
#
#                                           Description Page Count
# 0   La Force des forts (titre original : The Stren...         26
# 1   Martin Eden est un jeune marin au long cours. ...        434
# 2   L'aventure de Croc Blanc, d'abord publiée en 1...        170
# 3   Durant l'été 1902, Jack London va descendre da...        268
# 4   Résumé de la nouvelle qui donne son titre à ce...        244
# ..                                                ...        ...
# 95                                Nouvelle traduction        352
# 96  « C’est lorsqu’on commence à entretenir une re...         49
# 97  Venez découvrir le roman de George Orwell grâc...         42
# 98  Écrit en 1948, publié en 1949, le célèbre 1984...        318
# 99  La Ferme des animaux (titre original : Animal ...        100
#
# [100 rows x 6 columns]

# %%
df['Published Date'] = pd.to_datetime(df['Published Date'], errors='coerce').dt.date
df
# Out:
#            Author                                              Title  \
# 0     Jack London                                 La force des forts
# 1     Jack London                                        Martin Eden
# 2     Jack London                                         Croc-Blanc
# 3     Jack London                               Le Peuple de l'abîme
# 4     Jack London                                  Construire un feu
# ..            ...                                                ...
# 95  George Orwell                  Mil neuf cent quatre-vingt-quatre
# 96  George Orwell                   Sommes-nous ce que nous lisons ?
# 97  George Orwell  La Ferme des animaux de George Orwell (fiche d...
# 98  George Orwell                                               1984
# 99  George Orwell                               La ferme des animaux
#
#    Published Date            Categories  \
# 0      2022-05-26               Fiction
# 1      2023-01-03               Fiction
# 2      2019-01-28      Juvenile Fiction
# 3      2023-01-25  Literary Collections
# 4      2022-12-11               Fiction
# ..            ...                   ...
# 95            NaT               Fiction
# 96     2022-04-13    Literary Criticism
# 97     2019-10-22                   N/A
# 98     2021-06-01               Fiction
# 99     2021-09-17               Fiction
#
#                                           Description Page Count
# 0   La Force des forts (titre original : The Stren...         26
# 1   Martin Eden est un jeune marin au long cours. ...        434
# 2   L'aventure de Croc Blanc, d'abord publiée en 1...        170
# 3   Durant l'été 1902, Jack London va descendre da...        268
# 4   Résumé de la nouvelle qui donne son titre à ce...        244
# ..                                                ...        ...
# 95                                Nouvelle traduction        352
# 96  « C’est lorsqu’on commence à entretenir une re...         49
# 97  Venez découvrir le roman de George Orwell grâc...         42
# 98  Écrit en 1948, publié en 1949, le célèbre 1984...        318
# 99  La Ferme des animaux (titre original : Animal ...        100
#
# [100 rows x 6 columns]

# %%
df['Published Date'] = df['Published Date'].fillna('1900-01-01')
df
# Out:
#            Author                                              Title  \
# 0     Jack London                                 La force des forts
# 1     Jack London                                        Martin Eden
# 2     Jack London                                         Croc-Blanc
# 3     Jack London                               Le Peuple de l'abîme
# 4     Jack London                                  Construire un feu
# ..            ...                                                ...
# 95  George Orwell                  Mil neuf cent quatre-vingt-quatre
# 96  George Orwell                   Sommes-nous ce que nous lisons ?
# 97  George Orwell  La Ferme des animaux de George Orwell (fiche d...
# 98  George Orwell                                               1984
# 99  George Orwell                               La ferme des animaux
#
#    Published Date            Categories  \
# 0      2022-05-26               Fiction
# 1      2023-01-03               Fiction
# 2      2019-01-28      Juvenile Fiction
# 3      2023-01-25  Literary Collections
# 4      2022-12-11               Fiction
# ..            ...                   ...
# 95     1900-01-01               Fiction
# 96     2022-04-13    Literary Criticism
# 97     2019-10-22                   N/A
# 98     2021-06-01               Fiction
# 99     2021-09-17               Fiction
#
#                                           Description Page Count
# 0   La Force des forts (titre original : The Stren...         26
# 1   Martin Eden est un jeune marin au long cours. ...        434
# 2   L'aventure de Croc Blanc, d'abord publiée en 1...        170
# 3   Durant l'été 1902, Jack London va descendre da...        268
# 4   Résumé de la nouvelle qui donne son titre à ce...        244
# ..                                                ...        ...
# 95                                Nouvelle traduction        352
# 96  « C’est lorsqu’on commence à entretenir une re...         49
# 97  Venez découvrir le roman de George Orwell grâc...         42
# 98  Écrit en 1948, publié en 1949, le célèbre 1984...        318
# 99  La Ferme des animaux (titre original : Animal ...        100
#
# [100 rows x 6 columns]

# %%
df['Published Date'] = pd.to_datetime(df['Published Date'], errors='coerce')
df
# Out:
#            Author                                              Title  \
# 0     Jack London                                 La force des forts
# 1     Jack London                                        Martin Eden
# 2     Jack London                                         Croc-Blanc
# 3     Jack London                               Le Peuple de l'abîme
# 4     Jack London                                  Construire un feu
# ..            ...                                                ...
# 95  George Orwell                  Mil neuf cent quatre-vingt-quatre
# 96  George Orwell                   Sommes-nous ce que nous lisons ?
# 97  George Orwell  La Ferme des animaux de George Orwell (fiche d...
# 98  George Orwell                                               1984
# 99  George Orwell                               La ferme des animaux
#
#    Published Date            Categories  \
# 0      2022-05-26               Fiction
# 1      2023-01-03               Fiction
# 2      2019-01-28      Juvenile Fiction
# 3      2023-01-25  Literary Collections
# 4      2022-12-11               Fiction
# ..            ...                   ...
# 95     1900-01-01               Fiction
# 96     2022-04-13    Literary Criticism
# 97     2019-10-22                   N/A
# 98     2021-06-01               Fiction
# 99     2021-09-17               Fiction
#
#                                           Description Page Count
# 0   La Force des forts (titre original : The Stren...         26
# 1   Martin Eden est un jeune marin au long cours. ...        434
# 2   L'aventure de Croc Blanc, d'abord publiée en 1...        170
# 3   Durant l'été 1902, Jack London va descendre da...        268
# 4   Résumé de la nouvelle qui donne son titre à ce...        244
# ..                                                ...        ...
# 95                                Nouvelle traduction        352
# 96  « C’est lorsqu’on commence à entretenir une re...         49
# 97  Venez découvrir le roman de George Orwell grâc...         42
# 98  Écrit en 1948, publié en 1949, le célèbre 1984...        318
# 99  La Ferme des animaux (titre original : Animal ...        100
#
# [100 rows x 6 columns]

# %%
# Remplacer "N/A" par NaN pour une meilleure détection
df.replace("N/A", pd.NA, inplace=True)
missing_values = df.isna().sum()
missing_values
# Out:
# Author             0
# Title              0
# Published Date     0
# Categories        35
# Description       19
# Page Count         2
# dtype: int64

# %%
# Remplacer les valeurs manquantes (NaN) dans chaque colonne
df['Published Date'] = df['Published Date'].fillna('0001-01-01')
df['Categories'] = df['Categories'].fillna('Uncategorized')
df['Description'] = df['Description'].fillna('No Description Available')
df['Page Count'] = df['Page Count'].fillna(0).astype(int)

df
# Out:
#            Author                                              Title  \
# 0     Jack London                                 La force des forts
# 1     Jack London                                        Martin Eden
# 2     Jack London                                         Croc-Blanc
# 3     Jack London                               Le Peuple de l'abîme
# 4     Jack London                                  Construire un feu
# ..            ...                                                ...
# 95  George Orwell                  Mil neuf cent quatre-vingt-quatre
# 96  George Orwell                   Sommes-nous ce que nous lisons ?
# 97  George Orwell  La Ferme des animaux de George Orwell (fiche d...
# 98  George Orwell                                               1984
# 99  George Orwell                               La ferme des animaux
#
#    Published Date            Categories  \
# 0      2022-05-26               Fiction
# 1      2023-01-03               Fiction
# 2      2019-01-28      Juvenile Fiction
# 3      2023-01-25  Literary Collections
# 4      2022-12-11               Fiction
# ..            ...                   ...
# 95     1900-01-01               Fiction
# 96     2022-04-13    Literary Criticism
# 97     2019-10-22         Uncategorized
# 98     2021-06-01               Fiction
# 99     2021-09-17               Fiction
#
#                                           Description  Page Count
# 0   La Force des forts (titre original : The Stren...          26
# 1   Martin Eden est un jeune marin au long cours. ...         434
# 2   L'aventure de Croc Blanc, d'abord publiée en 1...         170
# 3   Durant l'été 1902, Jack London va descendre da...         268
# 4   Résumé de la nouvelle qui donne son titre à ce...         244
# ..                                                ...         ...
# 95                                Nouvelle traduction         352
# 96  « C’est lorsqu’on commence à entretenir une re...          49
# 97  Venez découvrir le roman de George Orwell grâc...          42
# 98  Écrit en 1948, publié en 1949, le célèbre 1984...         318
# 99  La Ferme des animaux (titre original : Animal ...         100
#
# [100 rows x 6 columns]
# /tmp/ipykernel_116599/1507908044.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Page Count'] = df['Page Count'].fillna(0).astype(int)  # Par défaut, 0 pour les pages

# %%
df['Published Date'] = pd.to_datetime(df['Published Date']).dt.date
df
# Out:
#            Author                                              Title  \
# 0     Jack London                                 La force des forts
# 1     Jack London                                        Martin Eden
# 2     Jack London                                         Croc-Blanc
# 3     Jack London                               Le Peuple de l'abîme
# 4     Jack London                                  Construire un feu
# ..            ...                                                ...
# 95  George Orwell                  Mil neuf cent quatre-vingt-quatre
# 96  George Orwell                   Sommes-nous ce que nous lisons ?
# 97  George Orwell  La Ferme des animaux de George Orwell (fiche d...
# 98  George Orwell                                               1984
# 99  George Orwell                               La ferme des animaux
#
#    Published Date            Categories  \
# 0      2022-05-26               Fiction
# 1      2023-01-03               Fiction
# 2      2019-01-28      Juvenile Fiction
# 3      2023-01-25  Literary Collections
# 4      2022-12-11               Fiction
# ..            ...                   ...
# 95     1900-01-01               Fiction
# 96     2022-04-13    Literary Criticism
# 97     2019-10-22         Uncategorized
# 98     2021-06-01               Fiction
# 99     2021-09-17               Fiction
#
#                                           Description  Page Count
# 0   La Force des forts (titre original : The Stren...          26
# 1   Martin Eden est un jeune marin au long cours. ...         434
# 2   L'aventure de Croc Blanc, d'abord publiée en 1...         170
# 3   Durant l'été 1902, Jack London va descendre da...         268
# 4   Résumé de la nouvelle qui donne son titre à ce...         244
# ..                                                ...         ...
# 95                                Nouvelle traduction         352
# 96  « C’est lorsqu’on commence à entretenir une re...          49
# 97  Venez découvrir le roman de George Orwell grâc...          42
# 98  Écrit en 1948, publié en 1949, le célèbre 1984...         318
# 99  La Ferme des animaux (titre original : Animal ...         100
#
# [100 rows x 6 columns]

# %%
# Renommer les colonnes du DataFrame pour correspondre aux noms de la table MySQL
df.rename(columns={
    'Published Date': 'PublishedDate',
    'Page Count': 'PageCount'
}, inplace=True)

df
# Out:
# Index(['Author', 'Title', 'PublishedDate', 'Categories', 'Description',
#        'PageCount'],
#       dtype='object')

# %%
df.to_csv('authors_top5_table.csv', index=False, encoding='utf-8')
